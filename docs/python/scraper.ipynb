# %%
import csv
import datetime
import duckdb
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup

# %%
def get_results(racename, raceyear):
    
    # Sleep a little
    time.sleep(3)

    # Set the time and date for the output table
    UPDATE_TIMESTAMP = str(datetime.datetime.now())[0:19]

    # URLs for race, route and results
    URL_PCS_BASE = "https://www.procyclingstats.com/race/"
    URL_RACE = URL_PCS_BASE + racename + "/" + str(raceyear)
    URL_ROUTE = URL_RACE + "/route/"

    print()
    print("URL_RACE:", URL_RACE)

    # Get soup of the route to check if race is valid; and if so if it is a one day race or a stage race
    page = requests.get(URL_ROUTE)
    soup = BeautifulSoup(page.content, "html.parser")

    # Check if link is valid
    if soup.title is None or soup.title.text.startswith("Page not found"):
        print("RACE LINK NOT VALID!")
        return 0
    
    # List of results needed to scrape
    RESULTS_TO_SCRAPE = []

    # Find out if the race is a one day race or a stage race
    tables = soup.find_all("table")
    for table in tables:
        headers = table.find("thead").find_all("th")
        headers = [header.text.strip() for header in headers]
        if "Date" in headers:
            idx_date = headers.index("Date")
            idx_stage = headers.index("#")
            idx_distance = headers.index("Distance")
            idx_vertical = headers.index("Vertical meters")
            rows = table.find("tbody").find_all("tr")

            # If rows are found, it is a stage race, otherwise a one day race
            if rows:
                # Get the stages of the race
                for row_num, row in enumerate(rows):                    
                    cols = row.find_all("td")
                    stage_number = row_num + 1
                    stage_date = cols[idx_date].text
                    stage_name = cols[idx_stage].text
                    stage_distance = cols[idx_distance].text
                    stage_vertical = cols[idx_vertical].text
                    stage_link = "https://www.procyclingstats.com/" + cols[idx_stage].find("a")["href"] if cols[idx_stage].find("a") else None

                    if "Prologue" in stage_name:
                        stage_type = "Prologue"
                    elif "ITT" in stage_name:
                        stage_type = "ITT"
                    elif "TTT" in stage_name:
                        stage_type = "TTT"
                    else:
                        stage_type = "Normal stage"

                    # Ignore the final row in the table of all stages
                    if stage_name == "":
                        continue

                    RESULTS_TO_SCRAPE.append({
                        "Stage number": stage_number,
                        "Stage name": stage_name,
                        "Stage link": stage_link,
                        "Stage type": stage_type,
                        "Stage date": stage_date,
                        "Stage distance": stage_distance,
                        "Stage vertical meters": stage_vertical
                    })
                # Also add GC and perhaps different jerseys to the list of results to get
                RESULTS_TO_SCRAPE.append({
                    "Stage number": 99,
                    "Stage name": "GC",
                    "Stage link": URL_RACE + "/gc",
                    "Stage type": "GC",
                    "Stage date": "",
                    "Stage distance": "",
                    "Stage vertical meters": ""
                })     

            else:
                # If it is a one day race get the race date from the main page of the race
                page = requests.get(URL_RACE)
                soup = BeautifulSoup(page.content, "html.parser")
                info_list = soup.find('ul', class_='keyvalueList')
                for li in info_list.find_all('li'):
                    title_div = li.find('div', class_='title')
                    if title_div and 'Startdate:' in title_div.text:
                        value_div = li.find('div', class_='value')
                        if value_div:
                            odr_date = value_div.text.strip()

                RESULTS_TO_SCRAPE.append({
                    "Stage number": 99,
                    "Stage name": "Result",
                    "Stage link": URL_RACE + "/result",
                    "Stage type": "Result",
                    "Stage date": odr_date,
                    "Stage distance": "",
                    "Stage vertical meters": ""
                })     
                
            break

    conn = duckdb.connect()
    conn.execute("""
    CREATE TABLE ScrapedResults (
        RaceName            TEXT,
        RaceYear            INTEGER,
        StageNumber         INTEGER,
        StageName           TEXT,
        StageType           TEXT,
        StageDate           TEXT,
        RiderRank           TEXT,
        RiderName           TEXT,
        TeamName            TEXT,
        UCIPoints           TEXT,
        PCSPoints           TEXT,
        UpdateTimeStamp     TEXT
    )
    """)

    for r in RESULTS_TO_SCRAPE:
        time.sleep(2)
        URL_RESULT = r["Stage link"]
        STAGE_TYPE = r["Stage type"]
        STAGE_NAME = r["Stage name"]
        STAGE_DATE = r["Stage date"]
        STAGE_NUMBER = r["Stage number"]
        print(STAGE_NAME)
        
        page = requests.get(URL_RESULT)
        soup = BeautifulSoup(page.content, "html.parser")
        tables = soup.find_all("table")

        if STAGE_TYPE == "TTT":
            info_list = soup.find('ul', class_='ttt-results')
            for li in info_list.find_all("li"):
                for di in li.find_all("div"):
                    if "w10" in di.get("class"):
                        li_rank = di.text.strip()
                    elif "w90" in di.get("class"):
                        li_team = di.text.strip()
                    elif "w100" in di.get("class"):
                        table = di.find("table")
                        rows = table.find_all("tr")
                        for row in rows:
                            cols = row.find_all("td")
                            li_rider = cols[0].text.strip()
                            li_uci = cols[1].text.strip()
                            li_pcs = cols[2].text.strip().strip()
                            data = [
                                racename,
                                raceyear,
                                STAGE_NUMBER,
                                STAGE_NAME,
                                STAGE_TYPE,
                                STAGE_DATE,
                                li_rank,
                                li_rider,
                                li_team,
                                li_uci,
                                li_pcs,
                                UPDATE_TIMESTAMP
                            ]
                            conn.executemany("INSERT INTO ScrapedResults VALUES (?,?,?,?,?,?,?,?,?,?,?,?)", [data])

            continue

        relevant_table_found = False
        relevant_table_number = 0
        neutralized = False 
        for table_number, table in enumerate(tables):
            headers = table.find("thead").find_all("th")
            headers = [header.text.strip() for header in headers]     
            if STAGE_TYPE == "Normal stage":
                if ("UCI" in headers and "Time won/lost" not in headers):
                    relevant_table_number = table_number
                    relevant_table_found = True
                    break
                elif ("Rnk" in headers and "Prev" not in headers):
                    relevant_table_number = table_number
                    relevant_table_found = True
                    neutralized = True
                    break                    
            elif STAGE_TYPE == "GC":
                if "UCI" in headers and "Time won/lost" in headers:
                    relevant_table_number = table_number
                    relevant_table_found = True
                    break
            elif STAGE_TYPE == "ITT" or STAGE_TYPE == "Prologue":
                if "UCI" in headers and "Avg" in headers:
                    relevant_table_number = table_number
                    relevant_table_found = True
                    break
            elif STAGE_TYPE == "TTT":
                pass
            elif STAGE_TYPE == "Result":
                if "UCI" in headers and "Time" in headers:
                    relevant_table_number = table_number
                    relevant_table_found = True
                    break
            
        if relevant_table_found == False:
            continue

        table = tables[relevant_table_number]
        headers = table.find("thead").find_all("th")
        headers = [header.text.strip() for header in headers]
        idx_rank = headers.index("Rnk")
        idx_rider = headers.index("Rider")
        idx_team = headers.index("Team")
        idx_uci = 0 if neutralized else headers.index("UCI")
        idx_pcs = 0 if neutralized else headers.index("Pnt")

        rows = table.find("tbody").find_all("tr")
        for row_num, row in enumerate(rows):
            cols = row.find_all("td")
            # If the row isn't an actual result row, but a row with info on a relegation, it is removed
            if len(cols) < 2:
                continue
            if neutralized:
                data = [
                    racename,
                    raceyear,
                    STAGE_NUMBER,
                    STAGE_NAME,
                    STAGE_TYPE,
                    STAGE_DATE,
                    str(row_num + 1) if cols[idx_rank].text.strip() == "DF" else cols[idx_rank].text.strip(),
                    cols[idx_rider].text.strip(),
                    cols[idx_team].text.strip(),
                    '',
                    '',
                    UPDATE_TIMESTAMP
                ]                 
            else:
                data = [
                    racename,
                    raceyear,
                    STAGE_NUMBER,
                    STAGE_NAME,
                    STAGE_TYPE,
                    STAGE_DATE,
                    cols[idx_rank].text.strip(),
                    cols[idx_rider].text.strip(),
                    cols[idx_team].text.strip(),
                    cols[idx_uci].text.strip(),
                    cols[idx_pcs].text.strip(),
                    UPDATE_TIMESTAMP
                ]
            conn.executemany("INSERT INTO ScrapedResults VALUES (?,?,?,?,?,?,?,?,?,?,?,?)", [data])

    conn.execute("COPY ScrapedResults TO '../data/results_races/results_" + racename + "-" + str(raceyear) + ".csv' (HEADER, DELIMITER ',')")

# %%
NOW = datetime.datetime.now()
FROM = NOW + datetime.timedelta(days = -10)
TO = NOW + datetime.timedelta(days = 10)

RACES = []
with open("../data/races.csv", newline = '') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if datetime.datetime.strptime(row["RaceStart"], "%Y-%m-%d %H:%M:00") < NOW and datetime.datetime.strptime(row["RaceEnd"], "%Y-%m-%d %H:%M:00") > FROM and datetime.datetime.strptime(row["RaceEnd"], "%Y-%m-%d %H:%M:00") < TO:
            RACES.append(row["RaceName_PCS"])

for race in RACES:
    get_results(race, 2025)
# Out:
# URL_RACE: https://www.procyclingstats.com/race/vuelta-a-espana/2025
# Stage 1
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '1', 'Philipsen JasperAlpecin - Deceuninck', 'Alpecin - Deceuninck', '180', '80', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '2', 'Vernon EthanIsrael - Premier Tech', 'Israel - Premier Tech', '130', '50', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '3', 'Aular OrluisMovistar Team', 'Movistar Team', '95', '35', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '4', 'Viviani EliaLotto', 'Lotto', '80', '25', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '5', 'García Cortina IvánMovistar Team', 'Movistar Team', '60', '18', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '6', 'González DavidQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '45', '15', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '7', 'Coquard BryanCofidis', 'Cofidis', '40', '12', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '8', 'Silva Guillermo ThomasCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '35', '10', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '9', 'Pidcock ThomasQ36.5 Pro Cycling Teamfav_gc', 'Q36.5 Pro Cycling Team', '30', '8', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '10', 'Mihkels MadisEF Education - EasyPost', 'EF Education - EasyPost', '25', '6', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '11', 'van Dijke TimRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '20', '5', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '12', 'Turner BenINEOS Grenadiers', 'INEOS Grenadiers', '15', '4', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08',
'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '73', 'Ermakov RomanBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '74', 'Aleotti GiovanniRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '75', 'Gamper PatrickTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '76', 'Paasschens MathijsBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '77', 'Meintjes LouisIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '78', 'Verona CarlosLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '79', 'Tiberi AntonioBahrain - Victoriousfav_gc', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '80', 'Harper ChrisTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '81', 'Rolland BrieucGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '82', 'Campenaerts VictorTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '83', 'Denz NicoRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '84', 'Barceló FernandoCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '85', 'Großschartner FelixUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '86', 'Guardeño JaumeCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '87', 'Bennett GeorgeIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '88', 'Bernard JulienLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '89', 'Masnada FaustoXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '90', 'Zwiehoff BenRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '91', 'Riccitello MatthewIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '92', 'Braz Afonso ClémentGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '93', 'Schachmann MaximilianSoudal Quick-Step', 'Soudal Quick-Step', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '94', 'Raisberg NadavIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '95', 'Vervaeke LouisSoudal Quick-Step', 'Soudal Quick-Step', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '96', 'Beloki MarkelEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '97', 'Shaw JamesEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '98', 'Pellizzari GiulioRed Bull - BORA - hansgrohefav_gc', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '99', 'Nerurkar LukasEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '100', 'Hamilton ChrisTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '101', 'Koerdt BjornTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '102', 'Camprubí MarcelQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '103', 'Slock LiamLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '104', 'Sobrero MatteoRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '105', 'Ryan ArchieEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '106', 'Livyns ArjenLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '107', 'Frigo MarcoIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '108', 'Ourselin PaulCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '109', 'Knight OliverCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '110', 'Bagioli AndreaLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '111', 'de la Cruz DavidQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '112', 'García Pierna CarlosBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '113', 'Thierry PierreArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '114', 'De Buyst JasperLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '115', 'Howson DamienQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '116', 'Sepúlveda EduardoLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '117', 'Higuita SergioXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '118', 'Samitier SergioCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '119', 'Rodríguez CristiánArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '120', 'Landa MikelSoudal Quick-Stepfav_gc', 'Soudal Quick-Step', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '121', 'López Harold MartínXDS Astana Teamfav_gc', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '122', 'Zukowsky NickolasQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '123', 'Peters NansDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '124', 'Leemreize GijsTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '125', 'Træen TorsteinBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '126', 'van Baarle DylanTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '127', 'Fernández SinuhéBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '128', 'Fortunato LorenzoXDS Astana Teamfav_gc', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '129', 'Rivera Brandon SmithINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '130', 'Quinn SeanEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '131', 'Sheffield MagnusINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '132', 'Bernal EganINEOS Grenadiersfav_gc', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '133', 'Langellotti VictorINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '134', 'Aparicio MarioBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '135', 'Petilli SimoneIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '136', 'Balderstone AbelCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '137', 'Côté Pier-AndréIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '138', 'Kelderman WilcoTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '139', 'Craps LarsLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '140', 'De Pestel SanderDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '141', 'Hoole DaanLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '142', 'Dunbar EddieTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '143', 'Gall FelixDecathlon AG2R La Mondiale Teamfav_gc', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '144', 'Hessmann MichelMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '145', 'Poels WoutXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '146', 'Romo JavierMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '147', 'Tejada HaroldXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '148', 'Bisiaux LéoDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '149', 'Carr SimonCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '150', 'Vinokurov Nicolas XDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '151', 'Hirt JanIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '152', 'Haig JackBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '153', 'Pickering FinlayBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '154', 'de la Calle Hugo Burgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '155', 'Castrillo PabloMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '156', 'Buchmann EmanuelCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '157', 'Arcas JorgeMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '158', 'Verre Alessandro Arkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '159', 'Novak DomenUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '160', 'Staune-Mittet JohannesDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '161', 'Cavagna RémiGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '162', 'Faura José LuisBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '163', 'Roosen TimoTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '164', 'Glivar GalAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '165', 'Bayer TobiasAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '166', 'Vergallito LucaAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '167', 'Scotson CallumDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '168', 'Rouland LouisArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '169', 'Guernalec VictorArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '170', 'Herrada JesúsCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '171', 'van der Lee Jardi ChristiaanEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '172', 'Juul-Jensen ChristopherTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '173', 'Bouwman Koen Team Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '174', 'Debruyne RamsesAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '175', 'Gregaard JonasLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '176', 'Bonneu KamielIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '177', 'Otruba JakubCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '178', 'Riesebeek OscarAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '179', 'Smith DionIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '180', 'Ghebreigzabhier AmanuelLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '181', 'Van Boven LucaIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '182', 'Bou JoanCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '183', 'Nicolau Joel Caja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 1, 'Stage 1', 'Normal stage', '23/08', '184', 'Vine JayUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# Stage 2
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '1', 'Vingegaard JonasTeam Visma | Lease a Bikefav_gc', 'Team Visma | Lease a Bike', '180', '80', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '2', 'Ciccone GiulioLidl - Trek', 'Lidl - Trek', '130', '50', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '3', 'Gaudu DavidGroupama - FDJ', 'Groupama - FDJ', '95', '35', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '4', 'Bernal EganINEOS Grenadiersfav_gc', 'INEOS Grenadiers', '80', '25', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '5', 'Almeida JoãoUAE Team Emirates - XRGfav_gc', 'UAE Team Emirates - XRG', '60', '18', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '6', 'Gall FelixDecathlon AG2R La Mondiale Teamfav_gc', 'Decathlon AG2R La Mondiale Team', '45', '15', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '7', 'Hindley JaiRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '40', '12', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '8', 'Ayuso JuanUAE Team Emirates - XRGfav_gc', 'UAE Team Emirates - XRG', '35', '10', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '9', 'Jorgenson MatteoTeam Visma | Lease a Bikefav_gc', 'Team Visma | Lease a Bike', '30', '8', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '10', 'Pidcock ThomasQ36.5 Pro Cycling Teamfav_gc', 'Q36.5 Pro Cycling Team', '25', '6', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '11', 'López Harold MartínXDS Astana Teamfav_gc', 'XDS Astana Team', '20', '5', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '12', 'Kuss SeppTeam Visma | Lease a Bikefav_gc', 'Team Visma | Lease a Bike', '15', '4', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '13', "O'Connor BenTeam Jayco AlUla", 'Team Jayco AlUla', '10', '3', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08',
ovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '88', 'Kelderman WilcoTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '89', 'Staune-Mittet JohannesDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '90', 'Peters NansDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '91', 'Ourselin PaulCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '92', 'Petilli SimoneIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '93', 'Zwiehoff BenRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '94', 'Großschartner FelixUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '95', 'Sheffield MagnusINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '96', 'Pickering FinlayBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '97', 'van der Lee Jardi ChristiaanEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '98', 'Knight OliverCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '99', 'Côté Pier-AndréIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '100', 'Vine JayUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '101', 'Denz NicoRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '102', 'Hamilton ChrisTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '103', 'Küng StefanGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '104', 'De Pooter DriesIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '105', 'Van Boven LucaIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '106', 'Labrosse JordanDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '107', 'Barceló FernandoCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '108', 'Leemreize GijsTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 2, 'Stage 2', 'Normal stage', '24/08', '109', 'Bouwman KoenTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ...
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '55', 'Raisberg NadavIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '56', 'Van Boven LucaIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '57', 'Aular OrluisMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '58', 'Gruel ThibaudGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '59', 'Vermaerke KevinTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '60', 'García Cortina IvánMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '61', 'Zwiehoff BenRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '62', 'Braz Afonso ClémentGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '63', 'Guardeño JaumeCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '64', 'Sobrero MatteoRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '65', 'Masnada FaustoXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '66', 'Fisher-Black FinnRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '67', 'Aleotti GiovanniRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '68', 'Gamper PatrickTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '69', 'Kelderman WilcoTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '70', 'Jungels BobINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '71', 'Stewart JakeIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '72', 'Bagioli AndreaLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '73', 'Landa MikelSoudal Quick-Stepfav_gc', 'Soudal Quick-Step', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '74', 'Soler MarcUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '75', 'Hamilton ChrisTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '76', 'Canal CarlosMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '77', 'Biermans JentheArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '78', 'de la Cruz DavidQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '79', 'López Harold MartínXDS Astana Teamfav_gc', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '80', 'Howson DamienQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '81', 'Christen FabioQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '82', 'de la Calle HugoBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '83', 'Roosen TimoTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '84', 'Kuss SeppTeam Visma | Lease a Bikefav_gc', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '85', 'Koerdt BjornTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '86', 'Gaudu DavidGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '87', 'Gregaard JonasLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '88', 'Tiberi AntonioBahrain - Victoriousfav_gc', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '89', 'Ciccone GiulioLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '90', 'Conci NicolaXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '91', 'Aparicio MarioBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '92', 'Staune-Mittet JohannesDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '93', 'Aniołkowski StanisławCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '94', 'Samitier SergioCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '95', 'Planckaert EdwardAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '96', 'Martinez Juan GuillermoTeam Picnic PostNL', 'Team Picnic PostNL', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '97', 'Silva Guillermo ThomasCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '98', 'Glivar GalAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '99', 'van Baarle DylanTeam Visma | Lease a Bike', 'Team Visma | Lease a Bike', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '100', 'Marit ArneIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '101', 'Bernard JulienLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '102', 'Juul-Jensen ChristopherTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '103', 'Viviani EliaLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '104', 'Cepeda Jefferson AlveiroMovistar Team', 'Movistar Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '105', 'Rouland LouisArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '106', 'González DavidQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '107', 'Buchmann EmanuelCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '108', 'Scotson CallumDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '109', 'Ghebreigzabhier AmanuelLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '110', 'Bayer TobiasAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '111', 'De Pooter DriesIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '112', 'Pickering FinlayBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '113', 'Molard RudyGroupama - FDJ', 'Groupama - FDJ', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '114', 'Vansevenant MauriSoudal Quick-Step', 'Soudal Quick-Step', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '115', 'Herrada JesúsCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '116', 'Sepúlveda EduardoLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '117', 'Novak DomenUAE Team Emirates - XRG', 'UAE Team Emirates - XRG', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '118', 'Zukowsky NickolasQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '119', 'van Dijke TimRed Bull - BORA - hansgrohe', 'Red Bull - BORA - hansgrohe', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '120', 'Shaw JamesEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '121', 'Vinokurov NicolasXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '122', 'Nerurkar LukasEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '123', 'Kwiatkowski MichałINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '124', 'Faura José LuisBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '125', 'Fortunato LorenzoXDS Astana Teamfav_gc', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '126', 'van der Lee Jardi ChristiaanEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '127', 'Craps LarsLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '128', 'Riesebeek OscarAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '129', 'Bonneu KamielIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '130', 'Quinn SeanEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '131', 'Bou JoanCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '132', 'Turner BenINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '133', 'Coquard BryanCofidis', 'Cofidis', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '134', 'Philipsen JasperAlpecin - Deceuninck', 'Alpecin - Deceuninck', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '135', 'Mihkels MadisEF Education - EasyPost', 'EF Education - EasyPost', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '136', 'Camprubí MarcelQ36.5 Pro Cycling Team', 'Q36.5 Pro Cycling Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '137', 'Verona CarlosLidl - Trek', 'Lidl - Trek', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '138', 'Smith DionIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '139', 'Bisiaux LéoDecathlon AG2R La Mondiale Team', 'Decathlon AG2R La Mondiale Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '140', 'Buratti NicolòBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '141', 'De Buyst JasperLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '142', 'Poels WoutXDS Astana Team', 'XDS Astana Team', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '143', 'Bernal EganINEOS Grenadiersfav_gc', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '144', 'Hirt JanIsrael - Premier Tech', 'Israel - Premier Tech', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '145', 'Petilli SimoneIntermarché - Wanty', 'Intermarché - Wanty', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '146', 'Nicolau JoelCaja Rural - Seguros RGA', 'Caja Rural - Seguros RGA', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '147', 'Haig JackBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '148', 'Slock LiamLotto', 'Lotto', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '149', 'Chumil Sergio GeovaniBurgos Burpellet BH', 'Burgos Burpellet BH', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '150', 'Lozouet LéandreArkéa - B&B Hotels', 'Arkéa - B&B Hotels', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '151', 'Foldager AndersTeam Jayco AlUla', 'Team Jayco AlUla', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '152', 'Rivera Brandon SmithINEOS Grenadiers', 'INEOS Grenadiers', '', '', '2025-09-12 22:49:01']
# ['vuelta-a-espana', 2025, 18, 'Stage 18 (ITT)', 'ITT', '11/09', '153', 'Paasschens MathijsBahrain - Victorious', 'Bahrain - Victorious', '', '', '2025-09-12 22:49:01']
